# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap as LSC
from pyproj import Geod
import module as m

# %%
m.paint_map('/Users/mihail/Desktop/Ocean_waves_project/GRD/pacific4min.grd')

# %%
chij = '/Users/mihail/Desktop/Ocean_waves_project/GRD/chij.grd'

DATA = m.triangle_time(chij, 27, 142)
m.paint(DATA)

# %%
m.paint('/Users/mihail/Desktop/Ocean_waves_project/GRD/pacific4min.grd')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 m.paint('/Users/mihail/Desktop/Ocean_waves_project/GRD/pacific4min.grd')
#
# File ~/Desktop/Ocean_waves_project/module.py:56, in paint(DATA)
#      54 def paint(DATA):
#      55 	fig, ax = plt.subplots(figsize=(12, 7))
# ---> 56 	im = ax.imshow(DATA, cmap='binary')
#      57 	fig.colorbar(im, ax=ax)
#      58 	plt.show()
#
# File /opt/miniconda3/lib/python3.12/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
# ...
