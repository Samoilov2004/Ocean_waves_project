# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap as LSC
from pyproj import Geod
import module as m

# %%
m.paint_map('/Users/mihail/Desktop/Ocean_waves_project/GRD/pacific4min.grd')

# %%
chij = '/Users/mihail/Desktop/Ocean_waves_project/GRD/chij.grd'

DATA = m.triangle_time(chij, 27, 142)
m.paint(DATA)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 3
#       1 chij = '/Users/mihail/Desktop/Ocean_waves_project/GRD/chij.grd'
# ----> 3 DATA = m.triangle_time(chij, 27, 142)
#       4 m.paint(DATA)
#
# AttributeError: module 'module' has no attribute 'triangle_time'
